# %%
import pickle

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))

# %%
X
# Out:
# array([[[ 36,  30,  64, ...,  49,  54,  45],
#         [ 37,  32,  61, ...,  49,  43,  43],
#         [ 36,  35,  60, ...,  48,  47,  45],
#         ...,
#         [ 94,  29,  36, ...,  39,  48,  45],
#         [ 29,  15,  22, ...,  32,  42,  47],
#         [ 19,  14,  14, ...,  31,  40,  47]],
#
#        [[173, 172, 173, ...,  83,  87,  84],
#         [172, 172, 171, ...,  78,  76,  84],
#         [171, 170, 171, ...,  95,  90,  86],
#         ...,
#         [  4,   4,   9, ...,  53,  63,  75],
#         [  2,   5,   3, ...,  58,  52,  68],
#         [  6,   7,   7, ...,  61,  64,  62]],
#
#        [[ 45,  47,  47, ...,  43,  41,  37],
#         [ 45,  47,  47, ...,  43,  43,  42],
#         [ 45,  47,  47, ...,  43,  43,  42],
#         ...,
#         [212, 213, 213, ..., 176, 172, 172],
#         [205, 198, 205, ..., 175, 177, 174],
#         [208, 211, 213, ..., 168, 168, 169]],
#
#        ...,
#
#        [[ 15,  48,  82, ...,  40,  24,   5],
#         [  6,  55,  79, ...,  38,  17,   6],
#         [  7,  48,  75, ...,  33,  23,  11],
#         ...,
#         [  1,   2,   2, ...,  70,  74,  63],
#         [  1,   4,  73, ...,  77,  81,  75],
#         [  1,  23,  80, ...,  82,  78,  78]],
#
#        [[118,  96,  97, ..., 158, 162, 162],
#         [100,  97,  72, ..., 163, 164, 151],
#         [ 82,  90,  96, ..., 150, 159, 163],
#         ...,
#         [149, 144, 146, ..., 144, 141, 143],
#         [116, 107, 100, ..., 140, 142, 145],
#         [141, 142, 140, ..., 140, 141, 143]],
#
#        [[183, 167, 163, ...,  54,  42,  56],
#         [162, 127, 113, ...,  57,  53,  60],
#         [140, 224,  83, ...,  67,  59,  42],
#         ...,
#         [ 43,  38,  40, ...,  10,  16,   8],
#         [ 39,  35,  34, ...,  11,  50,  21],
#         [ 31,  33,  28, ...,  12,  14,  34]]], dtype=uint8)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
X = X/255

# %%
X
# Out:
# array([[[0.65882353, 0.65098039, 0.65098039, ..., 0.45098039,
#          0.42745098, 0.40392157],
#         [0.65490196, 0.65098039, 0.65098039, ..., 0.45098039,
#          0.42745098, 0.40784314],
#         [0.65490196, 0.65490196, 0.65490196, ..., 0.45490196,
#          0.43137255, 0.40784314],
#         ...,
#         [0.69019608, 0.70588235, 0.7254902 , ..., 0.39607843,
#          0.39607843, 0.39607843],
#         [0.68627451, 0.6745098 , 0.6745098 , ..., 0.39215686,
#          0.39607843, 0.39607843],
#         [0.69803922, 0.70588235, 0.73333333, ..., 0.39607843,
#          0.39215686, 0.39607843]],
#
#        [[0.34901961, 0.35686275, 0.36470588, ..., 0.23529412,
#          0.23137255, 0.21176471],
#         [0.34901961, 0.36078431, 0.37647059, ..., 0.22745098,
#          0.21960784, 0.21960784],
#         [0.34901961, 0.36078431, 0.37647059, ..., 0.21568627,
#          0.21176471, 0.22745098],
#         ...,
#         [0.43137255, 0.42352941, 0.39607843, ..., 0.49019608,
#          0.47058824, 0.43921569],
#         [0.39607843, 0.39215686, 0.42352941, ..., 0.51372549,
#          0.4745098 , 0.4627451 ],
#         [0.39607843, 0.39215686, 0.4       , ..., 0.6745098 ,
#          0.4745098 , 0.50588235]],
#
#        [[0.22352941, 0.25098039, 0.29019608, ..., 0.2745098 ,
#          0.27058824, 0.21568627],
#         [0.29019608, 0.29803922, 0.33333333, ..., 0.27843137,
#          0.29019608, 0.25882353],
#         [0.30980392, 0.34117647, 0.35294118, ..., 0.32156863,
#          0.26666667, 0.27058824],
#         ...,
#         [0.67843137, 0.6       , 0.62745098, ..., 0.8627451 ,
#          0.84313725, 0.81960784],
#         [0.65098039, 0.63529412, 0.58823529, ..., 0.83137255,
#          0.82352941, 0.78823529],
#         [0.6745098 , 0.61960784, 0.55686275, ..., 0.83137255,
#          0.81568627, 0.77254902]],
#
#        ...,
#
#        [[0.23529412, 0.25098039, 0.22745098, ..., 0.60784314,
#          0.60392157, 0.58823529],
#         [0.23921569, 0.24705882, 0.24313725, ..., 0.60392157,
#          0.61176471, 0.59607843],
#         [0.25098039, 0.25490196, 0.23921569, ..., 0.60784314,
#          0.62352941, 0.60784314],
#         ...,
#         [0.23137255, 0.21568627, 0.23921569, ..., 0.32941176,
#          0.38431373, 0.39215686],
#         [0.21176471, 0.21960784, 0.11372549, ..., 0.37254902,
#          0.3372549 , 0.34901961],
#         [0.20392157, 0.22352941, 0.10196078, ..., 0.35686275,
#          0.36078431, 0.35686275]],
#
#        [[0.34117647, 0.33333333, 0.30588235, ..., 0.43921569,
#          0.48627451, 0.44313725],
#         [0.34901961, 0.35294118, 0.4       , ..., 0.41176471,
#          0.4627451 , 0.40392157],
#         [0.38039216, 0.41176471, 0.4       , ..., 0.44313725,
#          0.47843137, 0.42352941],
#         ...,
#         [0.54509804, 0.56078431, 0.61960784, ..., 0.61176471,
#          0.54117647, 0.61568627],
#         [0.54509804, 0.50196078, 0.56470588, ..., 0.54901961,
#          0.53333333, 0.54509804],
#         [0.54117647, 0.51764706, 0.54901961, ..., 0.59607843,
#          0.52156863, 0.54509804]],
#
#        [[0.99215686, 0.96862745, 0.97647059, ..., 0.59607843,
#          0.58039216, 0.56078431],
#         [0.98823529, 0.99607843, 0.98431373, ..., 0.51372549,
#          0.47843137, 0.46666667],
#         [0.99607843, 0.98431373, 0.99215686, ..., 0.42745098,
#          0.45098039, 0.38431373],
#         ...,
#         [0.37647059, 0.29019608, 0.34509804, ..., 0.24705882,
#          0.25098039, 0.26666667],
#         [0.42745098, 0.30588235, 0.23921569, ..., 0.2627451 ,
#          0.25098039, 0.25490196],
#         [0.38431373, 0.31372549, 0.35686275, ..., 0.3254902 ,
#          0.26666667, 0.32156863]]])

# %%
X = X.reshape(-1, 60, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape = X.shape[1:], activation = 'relu'))

model.add(Dense(2, activation = 'softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  640
#
#  max_pooling2d (MaxPooling2D  multiple                 0
#  )
#
#  conv2d_1 (Conv2D)           multiple                  36928
#
#  max_pooling2d_1 (MaxPooling  multiple                 0
#  2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  1384576
#
#  dense_1 (Dense)             multiple                  258
#
# =================================================================
# Total params: 1,422,402
# Trainable params: 1,422,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs=5, validation_split=0.1)

# %%
X.shape
# Out:
# (23000, 60, 60, 1)

# %%
import time

time.time()
# Out:
# 1581428129.5990093

# %%
type(1581428129.5990093)
# Out:
# float

# %%
X_test = pickle.load(open('X_test.pkl', 'rb'))
y_test = pickle.load(open('y_test.pkl', 'rb'))

# %%
X_test = X_test/255
X_test = X_test.reshape(-1, 60, 60, 1)
